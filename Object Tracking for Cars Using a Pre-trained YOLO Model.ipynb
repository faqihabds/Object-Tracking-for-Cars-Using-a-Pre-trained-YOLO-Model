# %% [markdown]
# Muhammad Faqih Abdussalam

# %% [markdown]
# # Bagian 1: Praktik Pemrograman (Python dan Google Colab)

# %% [markdown]
# ## Object Tracking Mobil dengan Pre-trained Model YOLO

# %%
# Load YOLOv8 Pre-trained Model
# !pip install ultralytics opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 33.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 29.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
model = YOLO('yolov8n.pt')  # Nano model (cepat dan ringan)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 73.4MB/s]

# %%
# Load video yang berisi mobil
from google.colab import drive
drive.mount('/content/drive')

video1_path = '/content/drive/MyDrive/Penting/portofolio/computer vision/1.mp4'
video2_path = '/content/drive/MyDrive/Penting/portofolio/computer vision/2.ts'
# Out:
# Mounted at /content/drive

# %%
# Tracking Mobil
import cv2

def detect_and_save(video_path, output_name):
    cap = cv2.VideoCapture(video_path)

    width  = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps    = cap.get(cv2.CAP_PROP_FPS)

    out = cv2.VideoWriter(output_name, cv2.VideoWriter_fourcc(*'XVID'), fps, (width, height))
    car_class_id = 2  # COCO class 'car'

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        results = model(frame)[0]

        for box in results.boxes:
            cls_id = int(box.cls[0])
            if cls_id == car_class_id:
                x1, y1, x2, y2 = map(int, box.xyxy[0])
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0,255,0), 2)
                cv2.putText(frame, 'Car', (x1, y1-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)

        out.write(frame)

    cap.release()
    out.release()
    print(f"Selesai: {output_name}")

# %%
# Video cctv 1
detect_and_save(video1_path,
                '/content/drive/MyDrive/Penting/portofolio/computer vision/1_output.avi')
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Speed: 6.1ms preprocess, 185.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 persons, 2 cars, 3 motorcycles, 1 truck, 156.4ms
# Speed: 7.8ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 6 motorcycles, 1 truck, 150.6ms
# Speed: 7.0ms preprocess, 150.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 persons, 1 car, 7 motorcycles, 1 truck, 155.3ms
# Speed: 6.1ms preprocess, 155.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 1 car, 5 motorcycles, 143.7ms
# Speed: 4.2ms preprocess, 143.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 2 cars, 6 motorcycles, 1 truck, 164.0ms
# Speed: 6.2ms preprocess, 164.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %%
# Video cctv 2
detect_and_save(video2_path,
                '/content/drive/MyDrive/Penting/portofolio/computer vision/2_output.avi')
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# Speed: 5.5ms preprocess, 225.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 9 cars, 3 buss, 3 trucks, 221.4ms
# Speed: 6.7ms preprocess, 221.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 10 cars, 3 buss, 2 trucks, 224.5ms
# Speed: 6.3ms preprocess, 224.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 2 trucks, 235.9ms
# Speed: 8.6ms preprocess, 235.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 2 trucks, 250.5ms
# Speed: 4.4ms preprocess, 250.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 4 trucks, 222.4ms
# Speed: 6.2ms preprocess, 222.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 3 buss, 3 trucks, 238.4ms
# ...

# %% [markdown]
# Link video hasil
# * [Output 1](https://drive.google.com/file/d/1xkZheE6Nj0YcTJwFRd9oJuFJj23HNN7b/view?usp=drive_link)
# * [Output 2](https://drive.google.com/file/d/1fO98ZYEYHLiUvpJ0VEO2qLfTTJe7aPFs/view?usp=drive_link)

# %% [markdown]
# # Bagian 2: Teori AI

# %% [markdown]
# ## Soal 2: Pertanyaan Teori Dasar

# %% [markdown]
# ### a. Apa yang dimaksud dengan Artificial Intelligence (AI)? Sebutkan dua contohnya dalam kehidupan sehari-hari.

# %% [markdown]
# #### Jawaban

# %% [markdown]
# * AI adalah cabang ilmu komputer yang memiliki tujuan agar mesin dapat meniru kecerdasan manusia.
# * Chatbot, chatgpt, dan rekomendasi produk pada e-commerce merupakan salah satu contoh kecerdasan buatan di kehidupan sehari-hari

# %% [markdown]
# ### b. Apa perbedaan antara Supervised Learning dan Unsupervised Learning? Berikan satu contoh untuk masing-masing.

# %% [markdown]
# #### Jawaban

# %% [markdown]
# * Supervised learning adalah jenis pembelajaran mesin yang dilatih dengan data yang sudah memiliki label, model belajar dari input dan output yang sudah diketahui.
# * Unsupervised learning adalah pembelajaran mesin yang dilatih dengan data yang tidak memiliki label, model mempelajari dan mengelompokan ciri atau pola yang sama secara mandiri.

# %% [markdown]
# ## Soal 3: Pertanyaan Konsep

# %% [markdown]
# ### a. Apa itu Feature dalam konteks machine learning? Mengapa penting untuk memilih fitur yang tepat saat membangun model?

# %% [markdown]
# #### Jawaban

# %% [markdown]
# * Feature adalah variabel yang digunakan sebagai input untuk membangun model machine learning.
# * Penting untuk memilih feature karena jika tidak feature yang tidak relevan dapat mennyebabkan overfitting dan hasil prediksi yang buruk.

# %% [markdown]
# ### b. Apa itu Fine-tuning dalam machine learning? Sebutkan satu kasus di mana fine-tuning berguna.

# %% [markdown]
# #### Jawaban

# %% [markdown]
# * Fine-tuning adalah proses penyesuaian ulang hyperparameter dari pre-trained model untuk mendapatkan  hasil pelatihan yang lebih baik saat digunakan pada dataset baru.
# * Fine-tuning digunakan saat melakukan transfer learning computer vision dengan menggunakan YOLO dari dateset besar seper ti COCO yang kemudian di fine-tuning pada dataset spesifik, dari yang awalnya mobil, dilakukan fine-tuning untuk mendeteksi jenis-jenis mobil. Fine-tuning dilakukan karena dapat mempersingkat waktu pelatihan dan menghasilkan performa yang baik pada dataset baru yang berukuran kecil.
